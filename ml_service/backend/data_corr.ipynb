# %%
if __name__ == "__main__":
    data = pd.read_csv("C:/Users/screb/Desktop/1cbit/ml_service/ml_service/datasets/nomenclature_limited.csv")
    print(data.info())
    print(data.describe())
    sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
